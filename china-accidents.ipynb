# %% [markdown]
# # China road accidents

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.plotly as py
import plotly.graph_objs as go
import altair as alt

# %%
accidents = pd.read_excel('accident.xls', sheet_name="Accidents")

# %%
deaths = pd.read_excel('accident.xls', sheet_name="Deaths")

# %%
new_header = list(accidents.iloc[:,0])

# %%
accidents = accidents.transpose()

# %%
accidents.columns = new_header

# %%
accidents = accidents.drop(accidents.index[0])

# %%
accidents.head()
# Out:
#      National Beijing Tianjin  Hebei Shanxi Inner Mongolia Liaoning Jilin  \
# 2005   450254    6364    4406  11187  13342           8453    10341  9659
# 2006   378781    5808    4913   8631  10981           6481     8671  7415
# 2007   327209    3943    4482   8503   9078           6305     8005  6956
# 2008   265204    3943    4048   7621   7867           5056     7214  5782
# 2009   238351    3814    3839   6802   7697           4166     6973  5277
#
#      Heilongjiang Shanghai  ... Chongqing Sichuan Guizhou Yunnan Tibet  \
# 2005         7506     9238  ...     10605   29628    3315   6870   845
# 2006         6732     6585  ...      9001   24338    2734   6692   751
# 2007         6715     3952  ...      8236   21598    2292   5425   638
# 2008         4528     2745  ...      7262   17037    2219   5037   600
# 2009         3331     2831  ...      5992   21680    1816   5075   678
#
#      Shaanxi Gansu Qinghai Ningxia Xinjiang
# 2005   12011  5414     952    3803     9526
# ...

# %%
deaths = deaths.transpose()

# %%
deaths.columns = new_header

# %%
deaths = deaths.drop(deaths.index[0])

# %%
deaths.head()
# Out:
#      National Beijing Tianjin Hebei Shanxi Inner Mongolia Liaoning Jilin  \
# 2005    98738    1515     970  4075   3819           2106     2919  2428
# 2006    89455    1373     878  3486   3413           1874     2611  2138
# 2007    81649    1182     849  3372   3062           1834     2534  1870
# 2008    73484     986    1225  2928   2910           1610     2280  1660
# 2009    67759     981     945  2766   2773           1440     2156  1483
#
#      Heilongjiang Shanghai  ... Chongqing Sichuan Guizhou Yunnan Tibet  \
# 2005         2164     1393  ...      1484    4415    1647   2901   540
# 2006         2164     1231  ...      1299    4090    1422   2627   536
# 2007         1906     1171  ...      1218    3790    1356   2323   438
# 2008         1703     1100  ...      1048    3344    1348   2082   384
# 2009         1419     1042  ...      1031    3057    1210   1888   369
#
#      Shaanxi Gansu Qinghai Ningxia Xinjiang
# 2005    2698  1799     736     796     3110
# ...

# %%
national = pd.DataFrame(accidents['National'])

# %%
years = list(national.index)

# %%
s = deaths.loc[:, 'National']

# %%
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 20
fig_size[1] = 12
plt.rcParams["figure.figsize"] = fig_size

# %%
accidents.plot()
accidents.plot(legend=False, logy=True)

# %%
accidents['Jiangxi'].plot()
accidents['Shanxi'].plot()
accidents['Guizhou'].plot(legend=True)
accidents['National'].plot(logy=True)

# %%
accidents.to_csv('accidents2.csv')
